# %%
import pandas as pd

# %%
df=pd.read_csv('/home/aapostolakis/Documents/ffpdata/results/aris/hypres_sk_RF_1M_2018only_mean_aucval_1.csv')

# %%
df_sorted = df.sort_values(by=['auc val.'], ascending=False)

# %%
df_sorted.iloc[0]['params']
# Out:
# "{'algo': 'RF', 'bootstrap': True, 'class_weights': {0: 1, 1: 300}, 'criterion': 'gini', 'feature_drop': (), 'max_depth': 1200, 'max_features': 5.0, 'min_samples_leaf': 30, 'min_samples_split': 50, 'n_estimators': 120}"

# %%
df_sorted[[c for c in df_sorted.columns if 'val.' in c]+['params']]
# Out:
#      accuracy val.  precision 1 val.  recall 1 val.  f1-score 1 val.  \
# 191       0.500633          0.000170       0.977011         0.000340
# 69        0.377570          0.000138       0.988506         0.000276
# 67        0.396120          0.000144       1.000000         0.000288
# 268       0.576519          0.000196       0.954023         0.000392
# 160       0.330371          0.000130       1.000000         0.000260
# ..             ...               ...            ...              ...
# 31        0.036175          0.000090       1.000000         0.000180
# 123       0.026952          0.000089       1.000000         0.000179
# 50        0.287343          0.000121       0.988506         0.000241
# 19        0.114794          0.000098       1.000000         0.000197
# 227       0.110021          0.000098       1.000000         0.000195
#
#      precision 0 val.  recall 0 val.  f1-score 0 val.  auc val.  TN val.  \
# ...

# %%
df_sorted.iloc[0]['trial']
# Out:
# 192
