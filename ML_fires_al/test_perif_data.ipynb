# %%
import pandas as pd

# %%
dfnorm=pd.read_csv('/mnt/nvme2tb/perifereia/20220902_norm.csv')

# %%
dfnorm.columns
# Out:
# Index(['index', 'Unnamed: 0', 'id', 'x', 'y', 'date', 'max_temp', 'min_temp',
#        'mean_temp', 'rain_7_days', 'dom_dir', 'dom_vel', 'res_max', 'dir_max',
#        'ndvi', 'evi', 'lst_night', 'lst_day', 'slope', 'curvature', 'aspect',
#        'dem', 'corine_gr21', 'corine_gr22', 'corine_gr23', 'corine_gr24',
#        'corine_gr31', 'corine_gr32', 'corine_gr33', 'fire', 'corine_gr1',
#        'corine_gr4', 'corine_gr5', 'firedate'],
#       dtype='object')

# %%
dfnorm
# Out:
# Empty DataFrame
# Columns: [index, Unnamed: 0, id, x, y, date, max_temp, min_temp, mean_temp, rain_7_days, dom_dir, dom_vel, res_max, dir_max, ndvi, evi, lst_night, lst_day, slope, curvature, aspect, dem, corine_gr21, corine_gr22, corine_gr23, corine_gr24, corine_gr31, corine_gr32, corine_gr33, fire, corine_gr1, corine_gr4, corine_gr5, firedate]
# Index: []
#
# [0 rows x 34 columns]

# %%
dforig=pd.read_csv('/mnt/nvme2tb/perifereia/20220826.csv')

# %%
dforig
# Out:
#        Unnamed: 0     id          x          y      date    max_temp  \
# 0               0      1  23.758767  38.254376  20220826  302.812836
# 1               1      2  23.759910  38.254378  20220826  302.812836
# 2               2      3  23.757627  38.253472  20220826  302.812836
# 3               3      4  23.758770  38.253475  20220826  302.812836
# 4               4      5  23.759913  38.253477  20220826  302.812836
# ...           ...    ...        ...        ...       ...         ...
# 46173       46173  46026  24.010137  37.701232  20220826  301.519897
# 46174       46174  46027  24.011272  37.701232  20220826  301.519897
# 46175       46175  46028  24.012406  37.701232  20220826  301.519897
# 46176       46176  46029  24.013541  37.701232  20220826  301.519897
# 46177       46177  46030  24.014675  37.701232  20220826  301.519897
#
#          min_temp   mean_temp  rain_7days  dom_dir  ...     curvature  \
# ...

# %%
dfst=pd.read_csv('/mnt/nvme2tb/perifereia/static.csv')

# %%
dfst
# Out:
#        Unnamed: 0       id         slope     curvature        aspect  \
# 0               0      1.0 -3.402823e+38 -3.402823e+38 -3.402823e+38
# 1               1      2.0 -3.402823e+38 -3.402823e+38 -3.402823e+38
# 2               2      3.0 -3.402823e+38 -3.402823e+38 -3.402823e+38
# 3               3      4.0 -3.402823e+38 -3.402823e+38 -3.402823e+38
# 4               4      5.0 -3.402823e+38 -3.402823e+38 -3.402823e+38
# ...           ...      ...           ...           ...           ...
# 46077       46077  46026.0  4.808639e+00 -1.443598e-01  2.903057e+02
# 46078       46078  46027.0  7.705463e+00  6.231782e-05  2.511923e+02
# 46079       46079  46028.0  1.083209e+01  8.647025e-02  2.083498e+02
# 46080       46080  46029.0  1.248612e+01  2.079460e-02  1.937130e+02
# 46081       46081  46030.0  1.359031e+01  9.689810e-03  1.921151e+02
#
#                 dem          x          y  corine_13  corine_4  ...  \
# 0     -3.402823e+38  23.758767  38.254376          0  0.102838  ...
# ...
