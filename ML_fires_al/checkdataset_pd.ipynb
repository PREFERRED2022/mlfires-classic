# %%
import pandas as pd

# %%
df=pd.read_csv("/data2/ffp/datasets/trainingsets/newfull/traindataset_new_norm.csv")

# %%
df
# Out:
#         dom_vel   res_max  max_dew_temp  min_dew_temp  mean_dew_temp  \
# 0      0.123914  1.044308      0.660740      0.625982       0.633226
# 1      0.159099  1.045045      0.651779      0.593272       0.607723
# 2      0.150598  1.076953      0.638552      0.598085       0.613687
# 3      0.131888  1.055599      0.638184      0.583396       0.593459
# 4      0.087409  1.026145      0.728094      0.624452       0.667115
# ...         ...       ...           ...           ...            ...
# 26599  0.071011  1.109352      0.709353      0.626898       0.676335
# 26600  0.071011  1.109598      0.709353      0.626898       0.676335
# 26601  0.071011  1.109843      0.709353      0.626898       0.676335
# 26602  0.071011  1.109352      0.709353      0.626898       0.676335
# 26603  0.071011  1.109598      0.709353      0.626898       0.676335
#
#        max_temp  min_temp  mean_temp  rain_7_days      ndvi       evi  \
# ...

# %%
df.mean()
# Out:
# dom_vel            0.211022
# res_max            1.106447
# max_dew_temp       0.780521
# min_dew_temp       0.725572
# mean_dew_temp      0.742056
# max_temp           0.749651
# min_temp           0.794469
# mean_temp          0.775876
# rain_7_days      128.573363
# ndvi               0.592561
# evi                0.428518
# lst_day            0.628464
# lst_night          0.619918
# pop                0.012290
# slope              0.946402
# road_dens          0.101700
# dem                0.169565
# aspect             0.491747
# dtype: float64

# %%
df['rain_7_days'].min()
# Out:
# 116.16261288841989

# %%
dfunorm=pd.read_csv("/data2/ffp/datasets/trainingsets/newfull/traindataset_new.csv")

# %%
dfunorm['rain_7_days'].min()
# Out:
# 0.0

# %%
dfunorm['rain_7_days'].max()
# Out:
# 0.2506699860095978

# %%
dfunorm['rain_7_days'].describe()
# Out:
# count    27092.000000
# mean         0.003249
# std          0.009593
# min          0.000000
# 25%          0.000006
# 50%          0.000146
# 75%          0.001756
# max          0.250670
# Name: rain_7_days, dtype: float64
