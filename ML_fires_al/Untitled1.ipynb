# %%
import pandas as pd

# %%
df = pd.read_csv('results/test_results_june_test.csv1.csv')

# %%
df
# Out:
#    Unnamed: 0      date  accuracy test  precision 1 test  recall 1 test  \
# 0           0  20190606       0.615219               0.0            0.0
# 1           1  20190601       0.536926               0.0            0.0
#
#    f1-score 1 test  True Negative 1  False Positive 1  False Negative 1  \
# 0              0.0           226932            141932                 0
# 1              0.0           193534            166914                 0
#
#    True Positive 1  accuracy 0 test  precision 0 test  recall 0 test  \
# 0                0         0.615219               1.0       0.615219
# 1                0         0.536926               1.0       0.536926
#
#    f1-score 0 test  auc test  True Negative 0  False Positive 0  \
# 0         0.761778       0.0           226932            141932
# 1         0.698701       0.0           193534            166914
#
#    False Negative 0  True Positive 0  predict time
# 0                 0                0      1.442897
# ...

# %%
df['True Negative 1'].sum()
# Out:
# 420466

# %%
df2 = df.append(pd.Series(name = 'sums'))
# Out:
# /home/sgirtsou/miniconda3/envs/ml/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#       Unnamed: 0        date  accuracy test  precision 1 test  recall 1 test  \
# 0            0.0  20190606.0       0.615219               0.0            0.0
# 1            1.0  20190601.0       0.536926               0.0            0.0
# sums         NaN         NaN            NaN               NaN            NaN
#
#       f1-score 1 test  True Negative 1  False Positive 1  False Negative 1  \
# 0                 0.0         226932.0          141932.0               0.0
# 1                 0.0         193534.0          166914.0               0.0
# sums              NaN              NaN               NaN               NaN
#
#       True Positive 1  accuracy 0 test  precision 0 test  recall 0 test  \
# 0                 0.0         0.615219               1.0       0.615219
# 1                 0.0         0.536926               1.0       0.536926
# sums              NaN              NaN               NaN            NaN
#
# ...

# %%
df2['True Negative 1']['sums']=df['True Negative 1'].sum()

# %%
df2
# Out:
#       Unnamed: 0        date  accuracy test  precision 1 test  recall 1 test  \
# 0            0.0  20190606.0       0.615219               0.0            0.0
# 1            1.0  20190601.0       0.536926               0.0            0.0
# sums         NaN         NaN            NaN               NaN            NaN
#
#       f1-score 1 test  True Negative 1  False Positive 1  False Negative 1  \
# 0                 0.0         226932.0          141932.0               0.0
# 1                 0.0         193534.0          166914.0               0.0
# sums              NaN         420466.0               NaN               NaN
#
#       True Positive 1  accuracy 0 test  precision 0 test  recall 0 test  \
# 0                 0.0         0.615219               1.0       0.615219
# 1                 0.0         0.536926               1.0       0.536926
# sums              NaN              NaN               NaN            NaN
#
# ...
