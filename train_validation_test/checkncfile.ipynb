# %%
import xarray as xr
import re
import pandas as pd

# %%
ds=xr.open_dataset('/mnt/nvme2tb/ffp/datasets/test/2020/final_dataset/20200820_df.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (y: 1368, x: 1812)
# Coordinates:
#   * y              (y) float64 41.77 41.76 41.76 41.75 ... 34.73 34.73 34.72
#   * x              (x) float64 19.25 19.25 19.26 19.26 ... 28.57 28.57 28.58
# Data variables: (12/18)
#     dom_dir        (y, x) float32 ...
#     dom_vel        (y, x) float32 ...
#     res_max        (y, x) float32 ...
#     dir_max        (y, x) float32 ...
#     mean_dew_temp  (y, x) float32 ...
#     min_dew_temp   (y, x) float32 ...
#     ...             ...
#     ndvi           (y, x) float32 ...
#     lst_day        (y, x) float32 ...
#     lst_night      (y, x) float32 ...
#     fire           (y, x) float32 ...
#     weekday        (y, x) float64 ...
#     month          (y, x) float64 ...

# %%
firedate=re.search('^(.*?)_df\.nc', '20200820_df.nc').group(1)

# %%
firedate
# Out:
# '20200820'

# %%
dict({'firedate':'20200820'},**{None})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 dict({'firedate':'20200820'},**{None})
#
# TypeError: dict() argument after ** must be a mapping, not set

# %%
type({'firedate':'20200820'})==dict
# Out:
# True

# %%
df=pd.read_csv('/mnt/nvme2tb/ffp/datasets/test/2019/greece/20190825_df_greece_norm.csv')

# %%
df
# Out:
#          index         y         x  dom_dir   dom_vel   res_max  dir_max  \
# 0            0  0.981039  0.666239      2.0  0.257156  0.257156      2.0
# 1            1  0.981039  0.666738      2.0  0.257156  0.257156      2.0
# 2            2  0.981039  0.667237      2.0  0.257156  0.257156      2.0
# 3            3  0.981039  0.672725      2.0  0.257156  0.257156      2.0
# 4            4  0.980314  0.665241      2.0  0.257156  0.257156      2.0
# ...        ...       ...       ...      ...       ...       ...      ...
# 500534  500534  0.005332  0.468146      0.0  0.183831  0.203285      8.0
# 500535  500535  0.004606  0.467647      0.0  0.183831  0.203285      8.0
# 500536  500536  0.004606  0.468645      0.0  0.183831  0.203285      8.0
# 500537  500537  0.004606  0.469144      0.0  0.183831  0.203285      8.0
# 500538  500538  0.003880  0.468645      0.0  0.183831  0.203285      8.0
#
#         max_dew_temp  min_dew_temp  mean_dew_temp  ...  corine_gr21  \
# ...
